# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("C:/Users/kunal/Downloads/stack-overflow-developer-survey-2025/survey_results_public.csv")
df1.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
df1.shape
# Out:
# (49123, 170)

# %%
df1.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=170)

# %%
df=df1[['Country','WorkExp','YearsCode','EdLevel','DevType','LanguageHaveWorkedWith','OrgSize','DatabaseHaveWorkedWith','PlatformHaveWorkedWith','Industry','WebframeHaveWorkedWith','RemoteWork','Currency','CompTotal']]
df.head()
# Out:
#        Country  WorkExp  YearsCode  \
# 0      Ukraine      8.0       14.0
# 1  Netherlands      2.0       10.0
# 2      Ukraine     10.0       12.0
# 3      Ukraine      4.0        5.0
# 4      Ukraine     21.0       22.0
#
#                                            EdLevel               DevType  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Developer, mobile
# 1              Associate degree (A.A., A.S., etc.)   Developer, back-end
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Developer, front-end
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Developer, back-end
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Engineering manager
#
#                               LanguageHaveWorkedWith  \
# 0                   Bash/Shell (all shells);Dart;SQL
# 1                                               Java
# 2                Dart;HTML/CSS;JavaScript;TypeScript
# 3                                    Java;Kotlin;SQL
# ...

# %%
df.shape
# Out:
# (49123, 14)

# %%
df.columns
# Out:
# Index(['Country', 'WorkExp', 'YearsCode', 'EdLevel', 'DevType',
#        'LanguageHaveWorkedWith', 'OrgSize', 'DatabaseHaveWorkedWith',
#        'PlatformHaveWorkedWith', 'Industry', 'WebframeHaveWorkedWith',
#        'RemoteWork', 'Currency', 'CompTotal'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49123 entries, 0 to 49122
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 35402 non-null  object
#  1   WorkExp                 42844 non-null  float64
#  2   YearsCode               43000 non-null  float64
#  3   EdLevel                 48087 non-null  object
#  4   DevType                 43636 non-null  object
#  5   LanguageHaveWorkedWith  31643 non-null  object
#  6   OrgSize                 34144 non-null  object
#  7   DatabaseHaveWorkedWith  25528 non-null  object
#  8   PlatformHaveWorkedWith  24234 non-null  object
#  9   Industry                33607 non-null  object
#  10  WebframeHaveWorkedWith  22970 non-null  object
#  11  RemoteWork              33747 non-null  object
#  12  Currency                35402 non-null  object
#  13  CompTotal               24839 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                   13721
# WorkExp                    6279
# YearsCode                  6123
# EdLevel                    1036
# DevType                    5487
# LanguageHaveWorkedWith    17480
# OrgSize                   14979
# DatabaseHaveWorkedWith    23595
# PlatformHaveWorkedWith    24889
# Industry                  15516
# WebframeHaveWorkedWith    26153
# RemoteWork                15376
# Currency                  13721
# CompTotal                 24284
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (43565, 14)

# %%
df.describe()
# Out:
#             WorkExp     YearsCode     CompTotal
# count  40137.000000  42366.000000  2.483700e+04
# mean      13.663527     16.718099  2.236806e+70
# std       10.878337     11.782057  3.525153e+72
# min        1.000000      1.000000  0.000000e+00
# 25%        5.000000      8.000000  5.500000e+04
# 50%       11.000000     14.000000  1.050000e+05
# 75%       20.000000     24.000000  2.400000e+05
# max      100.000000    100.000000  5.555556e+74

# %%
columns_check=['Country','EdLevel','DevType','Industry','RemoteWork','Currency']
for col in columns_check:
    print(f"\ncolumn: {col}")
    print(df[col].unique())
# Out:
# column: Country
# ['Ukraine' 'Netherlands' 'India' 'Georgia' 'Australia' 'Greece' 'Germany'
#  'Bangladesh' 'Brazil' 'United States of America' 'Lithuania'
#  'United Kingdom of Great Britain and Northern Ireland' 'Ireland' 'Sweden'
#  'Dominican Republic' 'Austria' 'Belgium' 'Czech Republic' 'Italy'
#  'Hungary' 'Malaysia' 'Switzerland' 'Egypt' 'Sri Lanka' 'Poland' 'Spain'
#  'Russian Federation' 'Serbia' 'Japan' 'France' 'Romania' 'Canada'
#  'Uruguay' 'United Arab Emirates' 'Argentina' 'Norway' 'Slovakia'
#  'Republic of Moldova' 'Peru' 'Portugal' 'Costa Rica' 'Croatia'
#  'Iran, Islamic Republic of...' 'Philippines' 'China' 'Finland' 'Colombia'
#  'Ethiopia' 'Israel' 'Bulgaria' 'Morocco' 'Mexico' 'Turkey' 'Bolivia'
#  'Nepal' 'Pakistan' 'South Africa' 'Tunisia' 'Singapore' 'Paraguay'
#  'Zimbabwe' 'Denmark' 'Trinidad and Tobago' 'Nigeria'
#  'Republic of North Macedonia' 'Cyprus' 'Latvia' 'Malta'
#  'Hong Kong (S.A.R.)' 'Luxembourg' 'Taiwan' 'Viet Nam' 'Chile'
# ...

# %%
df['Currency_Code'] = df['Currency'].str.extract(r'^(\w+)', expand=False)

# %%
df.head()
# Out:
#        Country  WorkExp  YearsCode  \
# 0      Ukraine      8.0       14.0
# 1  Netherlands      2.0       10.0
# 2      Ukraine     10.0       12.0
# 3      Ukraine      4.0        5.0
# 4      Ukraine     21.0       22.0
#
#                                            EdLevel               DevType  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Developer, mobile
# 1              Associate degree (A.A., A.S., etc.)   Developer, back-end
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Developer, front-end
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Developer, back-end
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Engineering manager
#
#                               LanguageHaveWorkedWith  \
# 0                   Bash/Shell (all shells);Dart;SQL
# 1                                               Java
# 2                Dart;HTML/CSS;JavaScript;TypeScript
# 3                                    Java;Kotlin;SQL
# ...

# %%
df['Currency_Code'].unique()
# Out:
# array(['EUR', 'UAH', 'USD', 'INR', 'AUD', 'BDT', 'BRL', 'GBP', 'SEK',
#        'CZK', 'PLN', 'HUF', 'MYR', 'CHF', 'EGP', 'LKR', 'RUB', 'RSD',
#        'JPY', 'RON', 'CAD', 'UYU', 'AED', 'ARS', 'NOK', 'CRC', 'PHP',
#        'CNY', 'ILS', 'BGN', 'MAD', 'MXN', 'TRY', 'BOB', 'NPR', 'ZAR',
#        'TND', 'PKR', 'SGD', 'PYG', 'AZN', 'DKK', 'NGN', 'IRR', 'HKD',
#        'TWD', 'VND', 'CLP', 'KRW', 'COP', 'UGX', 'JOD', 'IDR', 'ANG',
#        'MGA', 'DOP', 'GTQ', 'QAR', 'THB', 'BAM', 'AMD', 'MZN', 'KZT',
#        'HNL', 'GEL', 'KGS', 'MDL', 'GHS', 'DZD', 'KES', 'NZD', 'IMP',
#        'XPF', 'FJD', 'XCD', 'PEN', 'HTG', 'BHD', 'IQD', 'KHR', 'UZS',
#        'TJS', 'ZMW', 'YER', 'ALL', 'MUR', 'LBP', 'BYN', 'TTD', 'XOF',
#        'MVR', 'BWP', 'RWF', 'XAF', 'SAR', 'MMK', 'NAD', 'AFN', 'VES',
#        'LYD', nan, 'CDF', 'ETB', 'OMR', 'BTN', 'MRU', 'SYP', 'GYD', 'KWD',
#        'GIP', 'MOP', 'ISK', 'none', 'JMD', 'MKD', 'CUP', 'LAK', 'TMT',
# ...

# %%
df['Currency_Code'].isnull().sum()
# Out:
# 8214

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43565 entries, 0 to 49122
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 35351 non-null  object
#  1   WorkExp                 40137 non-null  float64
#  2   YearsCode               42366 non-null  float64
#  3   EdLevel                 43429 non-null  object
#  4   DevType                 43024 non-null  object
#  5   LanguageHaveWorkedWith  31639 non-null  object
#  6   OrgSize                 34035 non-null  object
#  7   DatabaseHaveWorkedWith  25527 non-null  object
#  8   PlatformHaveWorkedWith  24234 non-null  object
#  9   Industry                33586 non-null  object
#  10  WebframeHaveWorkedWith  22970 non-null  object
#  11  RemoteWork              33642 non-null  object
#  12  Currency                35351 non-null  object
#  13  CompTotal               24837 non-null  float64
# ...

# %%
df=df.drop('Currency',axis=1)

# %%
df.head()
# Out:
#        Country  WorkExp  YearsCode  \
# 0      Ukraine      8.0       14.0
# 1  Netherlands      2.0       10.0
# 2      Ukraine     10.0       12.0
# 3      Ukraine      4.0        5.0
# 4      Ukraine     21.0       22.0
#
#                                            EdLevel               DevType  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Developer, mobile
# 1              Associate degree (A.A., A.S., etc.)   Developer, back-end
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Developer, front-end
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Developer, back-end
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Engineering manager
#
#                               LanguageHaveWorkedWith  \
# 0                   Bash/Shell (all shells);Dart;SQL
# 1                                               Java
# 2                Dart;HTML/CSS;JavaScript;TypeScript
# 3                                    Java;Kotlin;SQL
# ...

# %%
rates_to_usd = {
    'EUR': 1.16, 'UAH': 0.024, 'USD': 1.0, 'INR': 0.012, 'AUD': 0.65, 'BDT': 0.009, 'BRL': 0.20,
    'GBP': 1.34, 'SEK': 0.096, 'CZK': 0.044, 'PLN': 0.25, 'HUF': 0.0028, 'MYR': 0.22, 'CHF': 1.15,
    'EGP': 0.021, 'LKR': 0.0033, 'RUB': 0.011, 'RSD': 0.009, 'JPY': 0.0067, 'RON': 0.25, 'CAD': 0.74,
    'UYU': 0.025, 'AED': 0.27, 'ARS': 0.001, 'NOK': 0.094, 'CRC': 0.0019, 'PHP': 0.018, 'CNY': 0.14,
    'ILS': 0.27, 'BGN': 0.58, 'MAD': 0.10, 'MXN': 0.058, 'TRY': 0.031, 'BOB': 0.14, 'NPR': 0.0075,
    'ZAR': 0.055, 'TND': 0.32, 'PKR': 0.0036, 'SGD': 0.74, 'PYG': 0.00014, 'AZN': 0.59, 'DKK': 0.15,
    'NGN': 0.00067, 'IRR': 0.000024, 'HKD': 0.13, 'TWD': 0.031, 'VND': 0.000041, 'CLP': 0.0011,
    'KRW': 0.00074, 'COP': 0.00026, 'UGX': 0.00027, 'JOD': 1.41, 'IDR': 0.000065, 'ANG': 0.56,
    'MGA': 0.00022, 'DOP': 0.017, 'GTQ': 0.13, 'QAR': 0.27, 'THB': 0.028, 'BAM': 0.58, 'AMD': 0.0026,
    'MZN': 0.016, 'KZT': 0.0021, 'HNL': 0.041, 'GEL': 0.37, 'KGS': 0.011, 'MDL': 0.056, 'GHS': 0.073,
    'DZD': 0.0074, 'KES': 0.007, 'NZD': 0.61, 'IMP': 1.34, 'XPF': 0.0092, 'FJD': 0.45, 'XCD': 0.37,
    'PEN': 0.27, 'HTG': 0.0074, 'BHD': 2.65, 'IQD': 0.00076, 'KHR': 0.00024, 'UZS': 0.000083,
    'TJS': 0.089, 'ZMW': 0.038, 'YER': 0.004, 'ALL': 0.011, 'MUR': 0.022, 'LBP': 0.000011,
    'BYN': 0.31, 'TTD': 0.15, 'XOF': 0.0017, 'MVR': 0.065, 'BWP': 0.073, 'RWF': 0.00079,
    'XAF': 0.0017, 'SAR': 0.27, 'MMK': 0.00048, 'NAD': 0.055, 'AFN': 0.014, 'VES': 0.028,
    'LYD': 0.21, None: None, 'CDF': 0.00039, 'ETB': 0.017, 'OMR': 2.60, 'BTN': 0.012, 'MRU': 0.026,
    'SYP': 0.0000008, 'GYD': 0.0048, 'KWD': 3.25, 'GIP': 1.34, 'MOP': 0.12, 'ISK': 0.0073,
    'none': None, 'JMD': 0.0065, 'MKD': 0.019, 'CUP': 0.042, 'LAK': 0.000048, 'TMT': 0.29,
    'SZL': 0.055, 'BBD': 0.50, 'MNT': 0.00029, 'TZS': 0.00038, 'BND': 0.74, 'SRD': 0.027,
    'KPW': 0.0011, 'BSD': 1.0, 'NIO': 0.027, 'GMD': 0.015, 'MWK': 0.00059, 'LSL': 0.055,
    'AOA': 0.0011, 'SDG': 0.0016, 'WST': 0.36, 'KYD': 1.20, 'PGK': 0.27, 'DJF': 0.0056,
    'BIF': 0.00035, 'BZD': 0.50, 'HRK': 0.15, 'SLL': 0.000038, 'CVE': 0.010, 'GNF': 0.00012
}


df['rate'] = df['Currency_Code'].map(rates_to_usd)
df['SalaryUSD']=df['CompTotal']*df['rate']
df=df.dropna(subset=['SalaryUSD'])

# %%
df.head()
# Out:
#        Country  WorkExp  YearsCode  \
# 0      Ukraine      8.0       14.0
# 1  Netherlands      2.0       10.0
# 2      Ukraine     10.0       12.0
# 3      Ukraine      4.0        5.0
# 4      Ukraine     21.0       22.0
#
#                                            EdLevel               DevType  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Developer, mobile
# 1              Associate degree (A.A., A.S., etc.)   Developer, back-end
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Developer, front-end
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Developer, back-end
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Engineering manager
#
#                               LanguageHaveWorkedWith  \
# 0                   Bash/Shell (all shells);Dart;SQL
# 1                                               Java
# 2                Dart;HTML/CSS;JavaScript;TypeScript
# 3                                    Java;Kotlin;SQL
# ...

# %%
df=df.drop(['CompTotal','Currency_Code','rate'],axis=1)

# %%
df.head()
# Out:
#        Country  WorkExp  YearsCode  \
# 0      Ukraine      8.0       14.0
# 1  Netherlands      2.0       10.0
# 2      Ukraine     10.0       12.0
# 3      Ukraine      4.0        5.0
# 4      Ukraine     21.0       22.0
#
#                                            EdLevel               DevType  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Developer, mobile
# 1              Associate degree (A.A., A.S., etc.)   Developer, back-end
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Developer, front-end
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Developer, back-end
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Engineering manager
#
#                               LanguageHaveWorkedWith  \
# 0                   Bash/Shell (all shells);Dart;SQL
# 1                                               Java
# 2                Dart;HTML/CSS;JavaScript;TypeScript
# 3                                    Java;Kotlin;SQL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24837 entries, 0 to 49122
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 24837 non-null  object
#  1   WorkExp                 24091 non-null  float64
#  2   YearsCode               24719 non-null  float64
#  3   EdLevel                 24819 non-null  object
#  4   DevType                 24837 non-null  object
#  5   LanguageHaveWorkedWith  22886 non-null  object
#  6   OrgSize                 21380 non-null  object
#  7   DatabaseHaveWorkedWith  18966 non-null  object
#  8   PlatformHaveWorkedWith  18334 non-null  object
#  9   Industry                23283 non-null  object
#  10  WebframeHaveWorkedWith  17075 non-null  object
#  11  RemoteWork              21259 non-null  object
#  12  SalaryUSD               24837 non-null  float64
# dtypes: float64(3), object(10)
# memory usage: 2.7+ MB

# %%
df.shape
# Out:
# (24837, 13)

# %%
df.isnull().sum()
# Out:
# Country                      0
# WorkExp                    746
# YearsCode                  118
# EdLevel                     18
# DevType                      0
# LanguageHaveWorkedWith    1951
# OrgSize                   3457
# DatabaseHaveWorkedWith    5871
# PlatformHaveWorkedWith    6503
# Industry                  1554
# WebframeHaveWorkedWith    7762
# RemoteWork                3578
# SalaryUSD                    0
# dtype: int64

# %%
df.describe()
# Out:
#             WorkExp     YearsCode     SalaryUSD
# count  24091.000000  24719.000000  2.483700e+04
# mean      13.713544     17.583276  2.236806e+70
# std       10.372522     11.306755  3.525153e+72
# min        1.000000      1.000000  0.000000e+00
# 25%        6.000000      9.000000  3.330000e+04
# 50%       11.000000     15.000000  7.200000e+04
# 75%       20.000000     25.000000  1.190000e+05
# max      100.000000    100.000000  5.555556e+74

# %%
#removing outliers
df=df[(df['SalaryUSD']>=1000) & (df['SalaryUSD']<=500000)]

# %%
df.shape
# Out:
# (23046, 13)

# %%
df.isnull().sum()
# Out:
# Country                      0
# WorkExp                    408
# YearsCode                   92
# EdLevel                     16
# DevType                      0
# LanguageHaveWorkedWith    1639
# OrgSize                   2534
# DatabaseHaveWorkedWith    5148
# PlatformHaveWorkedWith    5691
# Industry                   779
# WebframeHaveWorkedWith    6960
# RemoteWork                2629
# SalaryUSD                    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Country                      0
# WorkExp                    408
# YearsCode                   92
# EdLevel                     16
# DevType                      0
# LanguageHaveWorkedWith    1639
# OrgSize                   2534
# DatabaseHaveWorkedWith    5148
# PlatformHaveWorkedWith    5691
# Industry                   779
# WebframeHaveWorkedWith    6960
# RemoteWork                2629
# SalaryUSD                    0
# dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['WorkExp'].dropna(), kde=True, bins=20)
plt.show()

# %%
df['WorkExp'] = df['WorkExp'].fillna(0)
df['YearsCode'] = df['YearsCode'].fillna(df['YearsCode'].median())

# %%
df['EdLevel'] = df['EdLevel'].fillna(df['EdLevel'].mode()[0])
df['OrgSize'] = df['OrgSize'].fillna('Missing')
df['Industry'] = df['Industry'].fillna('Missing')
df['RemoteWork'] = df['RemoteWork'].fillna('Missing')

# %%
df.isnull().sum()
# Out:
# Country                      0
# WorkExp                      0
# YearsCode                    0
# EdLevel                      0
# DevType                      0
# LanguageHaveWorkedWith    1639
# OrgSize                      0
# DatabaseHaveWorkedWith    5148
# PlatformHaveWorkedWith    5691
# Industry                     0
# WebframeHaveWorkedWith    6960
# RemoteWork                   0
# SalaryUSD                    0
# dtype: int64

# %%
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd

# List of multi-select columns
multi_select_cols = ['LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith', 
                     'PlatformHaveWorkedWith', 'WebframeHaveWorkedWith']

for col in multi_select_cols:
    #  replace NaN with empty list
    df[col] = df[col].apply(lambda x: x if isinstance(x, list) else (x.split(';') if isinstance(x, str) else []))
    
    #  MultiLabelBinarizer 
    mlb = MultiLabelBinarizer()
    
    #  one-hot encoding
    encoded = pd.DataFrame(
        mlb.fit_transform(df[col]),
        columns=[f"{col}_{option}" for option in mlb.classes_],  
        index=df.index
    )
    
    # Concatenate encoded columns and drop the original column
    df = pd.concat([df.drop(col, axis=1), encoded], axis=1)

# %%
df.head()
# Out:
#        Country  WorkExp  YearsCode  \
# 0      Ukraine      8.0       14.0
# 1  Netherlands      2.0       10.0
# 2      Ukraine     10.0       12.0
# 3      Ukraine      4.0        5.0
# 4      Ukraine     21.0       22.0
#
#                                            EdLevel               DevType  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Developer, mobile
# 1              Associate degree (A.A., A.S., etc.)   Developer, back-end
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Developer, front-end
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Developer, back-end
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Engineering manager
#
#                     OrgSize                      Industry  \
# 0        20 to 99 employees                       Fintech
# 1      500 to 999 employees  Retail and Consumer Services
# 2                   Missing          Software Development
# 3  10,000 or more employees  Retail and Consumer Services
# ...

# %%
df.columns
# Out:
# Index(['Country', 'WorkExp', 'YearsCode', 'EdLevel', 'DevType', 'OrgSize',
#        'Industry', 'RemoteWork', 'SalaryUSD', 'LanguageHaveWorkedWith_Ada',
#        ...
#        'WebframeHaveWorkedWith_Nuxt.js', 'WebframeHaveWorkedWith_Phoenix',
#        'WebframeHaveWorkedWith_React', 'WebframeHaveWorkedWith_Ruby on Rails',
#        'WebframeHaveWorkedWith_Spring Boot', 'WebframeHaveWorkedWith_Svelte',
#        'WebframeHaveWorkedWith_Symfony', 'WebframeHaveWorkedWith_Vue.js',
#        'WebframeHaveWorkedWith_WordPress', 'WebframeHaveWorkedWith_jQuery'],
#       dtype='object', length=151)

# %%
single_select_cols = ['Country', 'EdLevel', 'DevType', 'Industry', 'RemoteWork','OrgSize']


df_encoded = pd.get_dummies(df, columns=single_select_cols)

# %%
df_encoded.head()
# Out:
#    WorkExp  YearsCode  SalaryUSD  LanguageHaveWorkedWith_Ada  \
# 0      8.0       14.0    61248.0                           0
# 1      2.0       10.0   104400.0                           0
# 2     10.0       12.0    53136.0                           0
# 3      4.0        5.0    36192.0                           0
# 4     21.0       22.0    60000.0                           0
#
#    LanguageHaveWorkedWith_Assembly  \
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
#
#    LanguageHaveWorkedWith_Bash/Shell (all shells)  LanguageHaveWorkedWith_C  \
# 0                                               1                         0
# 1                                               0                         0
# 2                                               0                         0
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23046 entries, 0 to 49122
# Columns: 377 entries, WorkExp to OrgSize_Missing
# dtypes: bool(232), float64(3), int32(142)
# memory usage: 18.3 MB

# %%
df_encoded.isnull().sum()
# Out:
# WorkExp                                                       0
# YearsCode                                                     0
# SalaryUSD                                                     0
# LanguageHaveWorkedWith_Ada                                    0
# LanguageHaveWorkedWith_Assembly                               0
#                                                              ..
# OrgSize_500 to 999 employees                                  0
# OrgSize_I don’t know                                          0
# OrgSize_Just me - I am a freelancer, sole proprietor, etc.    0
# OrgSize_Less than 20 employees                                0
# OrgSize_Missing                                               0
# Length: 377, dtype: int64

# %%
x= df_encoded.drop(['SalaryUSD'], axis=1)
y=df_encoded['SalaryUSD']

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=.2, random_state=42)
x_train.shape,x_test.shape
# Out:
# ((18436, 376), (4610, 376))

# %%
x.info
# Out:
# <bound method DataFrame.info of        WorkExp  YearsCode  LanguageHaveWorkedWith_Ada  \
# 0          8.0       14.0                           0
# 1          2.0       10.0                           0
# 2         10.0       12.0                           0
# 3          4.0        5.0                           0
# 4         21.0       22.0                           0
# ...        ...        ...                         ...
# 49089      1.0        2.0                           0
# 49098      8.0        6.0                           1
# 49106     29.0       29.0                           0
# 49121     10.0       14.0                           0
# 49122     10.0       15.0                           0
#
#        LanguageHaveWorkedWith_Assembly  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaler=scaler.fit_transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
#create a function to evaluate model
def evaluate_model(true,predicted):
    mae=mean_absolute_error(true,predicted)
    mse=mean_squared_error(true,predicted)
    rmse=np.sqrt(mean_squared_error(true,predicted))
    r2_square=r2_score(true,predicted)
    return mae, rmse, r2_square

# %%
models={
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(),
    'Lasso Regression': Lasso(),
    'ElasticNet': ElasticNet(),
    'SVR': SVR(),
    'KNN Regressor':KNeighborsRegressor(),
    'Gradient Boosting Regressor': GradientBoostingRegressor(),
    'Random Forest': RandomForestRegressor(),
    'DecisionTree': DecisionTreeRegressor()
}
for i in range(len(list(models))):
    model= list(models.values())[i]
    model.fit(x_train,y_train)
    #make predictions
    y_train_pred=model.predict(x_train)
    y_test_pred=model.predict(x_test)
    #evaluate train and test
    model_train_mae,model_train_rmse,model_train_r2=evaluate_model(y_train,y_train_pred)
    model_test_mae,model_test_rmse,model_test_r2=evaluate_model(y_test,y_test_pred)
    #
    #
    print(list(models.keys())[i])
    #
    print('modelmperformance for training set')
    print('-root mean squared error:{:.4f}'.format(model_train_rmse))
    print('-mean absolute error:{:.4f}'.format(model_train_mae))
    print('-r2 score: {:.4f}'.format(model_train_r2))
    print('-------------')
    #
    print('modelmperformance for test set')
    print('-root mean squared error:{:.4f}'.format(model_test_rmse))
    print('-mean absolute error:{:.4f}'.format(model_test_mae))
    print('-r2 score: {:.4f}'.format(model_test_r2))
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# modelmperformance for training set
# -root mean squared error:47365.5138
# -mean absolute error:31312.5395
# -r2 score: 0.5600
# -------------
# modelmperformance for test set
# -root mean squared error:6531824710021.6934
# -mean absolute error:254526570084.3176
# -r2 score: -8738858652649734.0000
# ...
#
#
# Ridge Regression
# modelmperformance for training set
# -root mean squared error:47384.8628
# -mean absolute error:31324.5956
# -r2 score: 0.5596
# -------------
# modelmperformance for test set
# -root mean squared error:48407.2867
# -mean absolute error:31572.3338
# -r2 score: 0.5200
# ...
#
#
# Lasso Regression
# modelmperformance for training set
# -root mean squared error:47369.8697
# -mean absolute error:31310.6430
# -r2 score: 0.5599
# -------------
# modelmperformance for test set
# -root mean squared error:48537.1818
# -mean absolute error:31587.0767
# -r2 score: 0.5175
# ...
#
#
# ElasticNet
# modelmperformance for training set
# -root mean squared error:59146.0673
# ...

# %%
#hyper parameter tunning
gb_params = {
    'n_estimators': [100, 200, 500],           # Number of boosting stages (trees)
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  # Step size shrinkage
    'max_depth': [3, 4, 5, 6],                 # Depth of each tree
    'min_samples_split': [2, 5, 10],           # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4],             # Minimum samples required at a leaf node
    'subsample': [0.6, 0.8, 1.0],              # Fraction of samples for each tree (adds randomness)
    'max_features': ['auto', 'sqrt', 'log2', None]  # Number of features to consider when splitting
}
rf_params={'max_depth':[5,8,15,None,10,20],
          'max_features':[5,7,'auto',8],
          'min_samples_split':[2,8,15,20,30],
          'n_estimators':[100,200,500,1000,10000]}

# %%
#model list for hyperparametertunning
randomcv_models=[('GB',GradientBoostingRegressor(), gb_params),
                 ('RF',RandomForestRegressor(), rf_params)]

# %%
#hyperparametertunning
from sklearn.model_selection import RandomizedSearchCV

model_param={}
for name,model,params in randomcv_models:
    random=RandomizedSearchCV(estimator=model,param_distributions=params,n_iter=15,cv=2,verbose=2,n_jobs=-1)
    random.fit(x_train,y_train)
    model_param[name]=random.best_params_
    

for model_name in model_param:
    print(f"-------------Best Params for {model_name} ---------------")
    print(model_param[model_name])
# Out:
# Fitting 2 folds for each of 15 candidates, totalling 30 fits
# Fitting 2 folds for each of 15 candidates, totalling 30 fits
# -------------Best Params for GB ---------------
# {'subsample': 0.8, 'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 6, 'learning_rate': 0.1}
# -------------Best Params for RF ---------------
# {'n_estimators': 10000, 'min_samples_split': 15, 'max_features': 8, 'max_depth': None}

# %%
models={
    'Random Forest': RandomForestRegressor(n_estimators= 1000, min_samples_split = 2, max_features = 7, max_depth = None),
    'Gradient Boost': GradientBoostingRegressor(subsample= 0.8, n_estimators= 500, min_samples_split= 2, min_samples_leaf=1, max_features= None, max_depth= 6, learning_rate= 0.05)
}
for i in range(len(list(models))):
    model= list(models.values())[i]
    model.fit(x_train,y_train)
    #make predictions
    y_train_pred=model.predict(x_train)
    y_test_pred=model.predict(x_test)
    #
    model_train_mae,model_train_rmse,model_train_r2=evaluate_model(y_train,y_train_pred)
    model_test_mae,model_test_rmse,model_test_r2=evaluate_model(y_test,y_test_pred)

    

    print(list(models.keys())[i])

    print('modelmperformance for training set')
    print('-root mean squared error:{:.4f}'.format(model_train_rmse))
    print('-mean absolute error:{:.4f}'.format(model_train_mae))
    print('-r2 score: {:.4f}'.format(model_train_r2))
    print('-------------')
    #
    print('modelmperformance for test set')
    print('-root mean squared error:{:.4f}'.format(model_test_rmse))
    print('-mean absolute error:{:.4f}'.format(model_test_mae))
    print('-r2 score: {:.4f}'.format(model_test_r2))
    print('='*35)
    print('\n')
# Out:
# Random Forest
# modelmperformance for training set
# -root mean squared error:19465.4069
# -mean absolute error:13344.5242
# -r2 score: 0.9257
# -------------
# modelmperformance for test set
# -root mean squared error:52039.3545
# -mean absolute error:35036.8006
# -r2 score: 0.4453
# ...
#
#
# Gradient Boost
# modelmperformance for training set
# -root mean squared error:32753.3373
# -mean absolute error:22552.0045
# -r2 score: 0.7896
# -------------
# modelmperformance for test set
# -root mean squared error:46400.6295
# -mean absolute error:29116.0911
# -r2 score: 0.5590
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
GradientBoost=GradientBoostingRegressor(subsample= 0.8, n_estimators= 500, min_samples_split= 2, min_samples_leaf=1, max_features= None, max_depth= 6, learning_rate= 0.05)
GradientBoost.fit(x_train_scaler,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, max_depth=6, n_estimators=500,
#                           subsample=0.8)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
import pickle
pickle.dump(GradientBoost,open('GradientBoost.pkl','wb'))

# %%
pickle.dump(scaler,open('scaler.pkl','wb'))
